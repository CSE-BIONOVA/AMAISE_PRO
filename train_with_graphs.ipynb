# %%
import matplotlib.pyplot as plt
# Open the text file for reading
with open('Result_9000.txt', 'r') as file:
    # Read lines from the file and store them in an array
    lines = file.readlines()

# Now 'lines' contains all the lines from the file as elements of an array
# You can access individual lines using array indexing
train_steps = (324000*0.8)//128
val_steps = (324000*0.2)//128
train_losses = []
val_losses = []
epochs = []
# Example: Print all lines
for i in range(len(lines)-1):
    train_loss = float(lines[i].strip().split(",")[1].split(":")[1])/train_steps
    train_losses.append(train_loss)
     # .strip() removes the newline character at the end of each line
    val_loss = float(lines[i].strip().split(",")[3].split(":")[1])/val_steps
    val_losses.append(val_loss)
    epochs.append(i+1)
fig, ax = plt.subplots(figsize=(10,7))
ax.plot(epochs, train_losses, label="train loss")
ax.plot(epochs, val_losses, label="val loss")
ax.set_xlabel("Epochs")
ax.set_ylabel("Loss")
ax.legend()

# %%
import matplotlib.pyplot as plt
# Open the text file for reading
with open('Result_9000_for_human_model_added_fc_b1024_e200.txt', 'r') as file:
    # Read lines from the file and store them in an array
    lines = file.readlines()

# Now 'lines' contains all the lines from the file as elements of an array
# You can access individual lines using array indexing
# train_steps = (324000*0.8)//128
# val_steps = (324000*0.2)//128
train_losses = []
val_losses = []
epochs = []
# Example: Print all lines
for i in range(len(lines)-1):
    train_loss = float(lines[i].strip().split(",")[2].split(":")[1])
    train_losses.append(train_loss)
     # .strip() removes the newline character at the end of each line
    val_loss = float(lines[i].strip().split(",")[4].split(":")[1])
    val_losses.append(val_loss)
    epochs.append(i+1)
fig, ax = plt.subplots(figsize=(10,7))
ax.plot(epochs, train_losses, label="train accuracy")
ax.plot(epochs, val_losses, label="val accuracy")
ax.set_xlabel("Epochs")
ax.set_ylabel("Accuracy")
# ax.set_title("batch size 128")
ax.legend()

# %%
#shark 1
import matplotlib.pyplot as plt
classes = [1, 2, 3, 4, 5, 6]
recall = [0.94, 0.80, 0.70, 0.74, 0.85, 0.64]
precision = [0.90, 0.86, 0.91, 0.88, 0.30, 0.05]
f1_score = [0.92, 0.83, 0.80, 0.14, 0.44, 0.10]

# %%
#shark 25
import matplotlib.pyplot as plt
classes = [1, 2, 3, 4, 5, 6]
recall = [0.94, 0.75, 0.70, 0.73, 0.85, 0.61]
precision = [0.23, 0.86, 0.92, 0.88, 0.27, 0.05]
f1_score = [0.36, 0.80, 0.79, 0.14, 0.42, 0.09]

# %%
#shark train
import matplotlib.pyplot as plt
classes = [1, 2, 3, 4, 5, 6]
recall = [0.94, 0.86, 0.82, 0.87, 0.88, 0.83]
precision = [0.92, 0.87, 0.80, 0.87, 0.88, 0.87]
f1_score = [0.93, 0.87, 0.81, 0.87, 0.88, 0.85]

# %%
# classes = [1, 2, 3, 4, 5, 6]
# recall = [0.99, 0.80, 0.84, 0.83, 0.88, 0.84]
# precision = [0.98, 0.92, 0.87, 0.97, 0.97, 0.97]
# f1_score = [0.98, 0.86, 0.85, 0.89, 0.92, 0.90]

fig, ax = plt.subplots(figsize=(10,7))
ax.bar(classes, recall, color ='maroon', width = 0.5)
# ax.plot(classes, precision, label="precision")
# ax.plot(classes, f1_score, label="f1_score")
ax.set_xlabel("classes")
ax.set_ylabel("measure")
ax.set_title("Recall")
# ax.set_ylim(0.5,1)
# ax.legend()
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
fig, ax = plt.subplots(figsize=(10,7))
ax.bar(classes, precision, color ='blue', width = 0.5)
# ax.plot(classes, precision, label="precision")
# ax.plot(classes, f1_score, label="f1_score")
ax.set_xlabel("classes")
ax.set_ylabel("measure")
ax.set_title("precision")
# Out:
# Text(0.5, 1.0, 'precision')

# %%
fig, ax = plt.subplots(figsize=(10,7))
ax.bar(classes, f1_score, color ='green', width = 0.5)
# ax.plot(classes, precision, label="precision")
# ax.plot(classes, f1_score, label="f1_score")
ax.set_xlabel("classes")
ax.set_ylabel("measure")
ax.set_title("f1_score")
# Out:
# Text(0.5, 1.0, 'f1_score')

# %%
import matplotlib.pyplot as plt
human_accuracy = [0.72, 0.71, 0.68, 0.66, 0.64]
shark_accuracy = [0.72, 0.79, 0.83, 0.89, 0.94]
x = ["shark_1", "shark_25", "shark_50", "shark_75", "shark_99"]
fig, ax = plt.subplots(figsize=(10,7))
ax.plot(x, human_accuracy, marker = 'o', label = "shark test set accuracy for human trained model")
ax.plot(x, shark_accuracy, marker = 'o', label = "shark test set accuracy for transfer learned shark model")
ax.legend()
ax.set_xlabel("test datasets")
ax.set_ylabel("Accuracy")
ax.set_ylim(0,1)
# Out:
# (0.0, 1.0)

# %%
import matplotlib.pyplot as plt

with open('../Logs/temp.log', 'r') as file:
    lines = file.readlines()
epochs = []
train_losses1 = []
for i in range(80):
    train_loss = float(lines[i].strip().split(",")[2].split(":")[1])
    train_losses1.append(train_loss)
    epochs.append(i+1)

with open('Result_9000_for_human_model_added_fc_b1024_e200.txt', 'r') as file2:
    lines2 = file2.readlines()
print(len(lines2))
train_losses2 = []
for i in range(80):
    train_loss = float(lines2[i].strip().split(",")[1].split(":")[1])
    train_losses2.append(train_loss)

x = ["shark_1", "shark_25", "shark_50", "shark_75", "shark_99"]
fig, ax = plt.subplots(figsize=(10,7))
ax.plot(epochs, train_losses1, label = "train loss for model 1")
ax.plot(epochs, train_losses2, label = "train loss for model 2")
ax.legend()
ax.set_xlabel("epochs")
ax.set_ylabel("Loss")
# ax.set_ylim(0,1)
# Out:
# 82
# Text(0, 0.5, 'Loss')

# %%
import matplotlib.pyplot as plt

with open('amaiseProWithRegGradNormb512e300lr0.0001.log', 'r') as file:
    lines = file.readlines()
epochs = []
train_losses_resnet = []
val_losses_resnet = []
for i in range(len(lines)):
    train_loss = float(lines[i].strip().split(",")[2].split(": ")[1])
    # print(train_loss)
    val_loss = float(lines[i].strip().split(",")[4].split(": ")[1])
    # print(val_loss)
    train_losses_resnet.append(train_loss)
    val_losses_resnet.append(val_loss)
    epochs.append(i+1)

with open('result_human_b512_e200.txt.log', 'r') as file_2:
    lines_2 = file_2.readlines()
epochs_model = []
train_losses_model = []
val_losses_model = []
print(len(lines_2))
for i in range(len(lines_2)):
    train_loss = float(lines_2[i].strip().split(",")[2].split(": ")[1])
    # print(train_loss)
    val_loss = float(lines_2[i].strip().split(",")[4].split(": ")[1])
    # print(val_loss)
    train_losses_model.append(train_loss)
    val_losses_model.append(val_loss)
    epochs_model.append(i+1)


fig, ax = plt.subplots(figsize=(10,7))
ax.plot(epochs, train_losses_resnet, label = "train loss for model with grad. norm. reg")
ax.plot(epochs, val_losses_resnet, label = "val loss for model with grad. norm. reg")
ax.plot(epochs_model, train_losses_model, label = "train loss for model without reg")
ax.plot(epochs_model, val_losses_model, label = "val loss for model without reg")

ax.legend()
ax.set_xlabel("epochs")
ax.set_ylabel("Loss")
# Out:
# 200
# Text(0, 0.5, 'Loss')

# %%
import matplotlib.pyplot as plt

with open('resnetb512e200lr0.0001.log', 'r') as file:
    lines = file.readlines()
epochs = []
train_acc_resnet = []
val_acc_resnet = []
for i in range(len(lines)):
    train_acc = float(lines[i].strip().split(",")[3].split(": ")[1])
    # print(train_loss)
    val_acc = float(lines[i].strip().split(",")[5].split(": ")[1])
    # print(val_loss)
    train_acc_resnet.append(train_acc)
    val_acc_resnet.append(val_acc)
    epochs.append(i+1)

with open('result_human_b512_e200.txt.log', 'r') as file_2:
    lines_2 = file_2.readlines()
epochs_model = []
train_acc_model = []
val_acc_model = []
print(len(lines_2))
for i in range(len(lines_2)):
    train_acc = float(lines_2[i].strip().split(",")[3].split(": ")[1])
    # print(train_loss)
    val_acc = float(lines_2[i].strip().split(",")[5].split(": ")[1])
    # print(val_loss)
    train_acc_model.append(train_acc)
    val_acc_model.append(val_acc)
    epochs_model.append(i+1)


fig, ax = plt.subplots(figsize=(10,7))
ax.plot(epochs, train_acc_resnet, label = "train accuracy for resnet with 2 blocks")
ax.plot(epochs, val_acc_resnet, label = "val accuracy for resnet with 2 blocks")
ax.plot(epochs_model, train_acc_model, label = "train accuracy for amaise pro")
ax.plot(epochs_model, val_acc_model, label = "val accuracy for amaisepro")

ax.legend()
ax.set_xlabel("epochs")
ax.set_ylabel("Accuracy")
# Out:
# 200
# Text(0, 0.5, 'Accuracy')

# %%
import matplotlib.pyplot as plt

with open('resnetb512e200lr0.0001.log', 'r') as file:
    lines = file.readlines()
epochs = []
train_losses_resnet = []
val_losses_resnet = []
for i in range(len(lines)):
    train_loss = float(lines[i].strip().split(",")[2].split(": ")[1])
    # print(train_loss)
    val_loss = float(lines[i].strip().split(",")[4].split(": ")[1])
    # print(val_loss)
    train_losses_resnet.append(train_loss)
    val_losses_resnet.append(val_loss)
    epochs.append(i+1)

with open('result_human_b512_e200.txt.log', 'r') as file_2:
    lines_2 = file_2.readlines()
epochs_model = []
train_losses_model = []
val_losses_model = []
print(len(lines_2))
for i in range(len(lines_2)):
    train_loss = float(lines_2[i].strip().split(",")[2].split(": ")[1])
    # print(train_loss)
    val_loss = float(lines_2[i].strip().split(",")[4].split(": ")[1])
    # print(val_loss)
    train_losses_model.append(train_loss)
    val_losses_model.append(val_loss)
    epochs_model.append(i+1)


fig, ax = plt.subplots(figsize=(10,7))
ax.plot(epochs, train_losses_resnet, label = "train loss for resnet")
ax.plot(epochs, val_losses_resnet, label = "val loss for resnet")
ax.plot(epochs_model, train_losses_model, label = "train loss for model without resnet")
ax.plot(epochs_model, val_losses_model, label = "val loss for model without resnet")

ax.legend()
ax.set_xlabel("epochs")
ax.set_ylabel("Loss")
# Out:
# 200
# Text(0, 0.5, 'Loss')

# %%
import matplotlib.pyplot as plt

with open('resnet2_3_b512e200lr0.0001.log', 'r') as file:
    lines = file.readlines()
epochs = []
train_losses_resnet = []
val_losses_resnet = []
for i in range(len(lines)):
    train_loss = float(lines[i].strip().split(",")[2].split(": ")[1])
    # print(train_loss)
    val_loss = float(lines[i].strip().split(",")[4].split(": ")[1])
    # print(val_loss)
    train_losses_resnet.append(train_loss)
    val_losses_resnet.append(val_loss)
    epochs.append(i+1)

with open('resnetb512e200lr0.0001.log', 'r') as file:
    lines_1 = file.readlines()
epochs_ = []
train_losses_resnet_ = []
val_losses_resnet_ = []
for i in range(len(lines_1)):
    train_loss_ = float(lines_1[i].strip().split(",")[2].split(": ")[1])
    # print(train_loss)
    val_loss_ = float(lines_1[i].strip().split(",")[4].split(": ")[1])
    # print(val_loss)
    train_losses_resnet_.append(train_loss_)
    val_losses_resnet_.append(val_loss_)
    epochs_.append(i+1)


with open('result_human_b512_e200.txt.log', 'r') as file_2:
    lines_2 = file_2.readlines()
epochs_model = []
train_losses_model = []
val_losses_model = []
print(len(lines_2))
for i in range(len(lines_2)):
    train_loss = float(lines_2[i].strip().split(",")[2].split(": ")[1])
    # print(train_loss)
    val_loss = float(lines_2[i].strip().split(",")[4].split(": ")[1])
    # print(val_loss)
    train_losses_model.append(train_loss)
    val_losses_model.append(val_loss)
    epochs_model.append(i+1)


fig, ax = plt.subplots(figsize=(10,7))
ax.plot(epochs, train_losses_resnet, label = "train loss for resnet_2_3")
# ax.plot(epochs, val_losses_resnet, label = "val loss for resnet_2_3")
ax.plot(epochs_, train_losses_resnet_, label = "train loss for resnet_1_1_1")
# ax.plot(epochs_, val_losses_resnet_, label = "val loss for resnet_1_1_1")
ax.plot(epochs_model, train_losses_model, label = "train loss for model without resnet")
# ax.plot(epochs_model, val_losses_model, label = "val loss for model without resnet")

ax.legend()
ax.set_xlabel("epochs")
ax.set_ylabel("Loss")
# Out:
# 200
# Text(0, 0.5, 'Loss')
